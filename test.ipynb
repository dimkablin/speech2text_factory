# %%
from src.ai_models.whisper.model import Whisper

# %%
model = Whisper()
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
import time

start_time = time.time()
result = model("src/data/test.wav")
print(result)
print(time.time()-start_time)
# Out:
# [' Встреча в пятницу было совещание с управлением по персоналу. И коллеги выразили мнение своё, но я думаю, что они не одни такие. О работе нашей команды. Было очень приятно слышать, когда сказали, что очень быстро ребята выполняют задачи без ошибок.']
# 5.503659009933472

# %%
model.get_config()
# Out:
# {'device': ['cpu', 'cuda:0', 'cuda:1'],
#  'language': ['russian',
#   'english',
#   'italian',
#   'french',
#   'spanish',
#   'german',
#   'ukrainian',
#   'polish',
#   'japanese',
#   'mandarin']}

# %%
'device' in model.__dict__
# Out:
# True

# %%
model.__dict__
# Out:
# {'model_name': 'openai/whisper-tiny',
#  'language': 'russian',
#  'device': 'cpu',
#  'path_to_model': 'src/ai_models/whisper/weigths/',
#  'torch_dtype': torch.float32,
#  'model': WhisperForConditionalGeneration(
#    (model): WhisperModel(
#      (encoder): WhisperEncoder(
#        (conv1): Conv1d(80, 768, kernel_size=(3,), stride=(1,), padding=(1,))
#        (conv2): Conv1d(768, 768, kernel_size=(3,), stride=(2,), padding=(1,))
#        (embed_positions): Embedding(1500, 768)
#        (layers): ModuleList(
#          (0-11): 12 x WhisperEncoderLayer(
#            (self_attn): WhisperSdpaAttention(
#              (k_proj): Linear(in_features=768, out_features=768, bias=False)
#              (v_proj): Linear(in_features=768, out_features=768, bias=True)
#              (q_proj): Linear(in_features=768, out_features=768, bias=True)
#              (out_proj): Linear(in_features=768, out_features=768, bias=True)
#            )
# ...

# %%
from src.ai_models.speech2text import MODELS_FACTORY
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
MODELS_FACTORY.get_model().get_model_name()
# Out:
# 'openai/whisper-tiny'

# %%
res = MODELS_FACTORY.get_model_config('openai/whisper-tiny')
res
# Out:
# {'device': ['cpu', 'cuda:0', 'cuda:1'],
#  'language': ['russian',
#   'english',
#   'italian',
#   'french',
#   'spanish',
#   'german',
#   'ukrainian',
#   'polish',
#   'japanese',
#   'mandarin']}

# %%
req = {'device': 'cpu','language': 'japanese'}

# %%
model = Whisper(**req)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
model.language
# Out:
# 'japanese'
